# %%
import os
os.environ['KAGGLE_USERNAME'] = "kgat"
os.environ['KAGGLE_KEY'] = "KGAT_8ba72e85f3b57572a930bce4cddf43ba"

# %%
# !pip install -q kaggle

# %%
# !kaggle datasets download -d abdallahalidev/plantvillage-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abdallahalidev/plantvillage-dataset
# License(s): CC-BY-NC-SA-4.0
# ...
# 100% 2.04G/2.04G [00:19<00:00, 266MB/s]
# 100% 2.04G/2.04G [00:19<00:00, 114MB/s]

# %%
# !unzip -q plantvillage-dataset.zip -d plantvillage

# %%
import os
import torch
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# %%
os.listdir("plantvillage")
# Out:
# ['plantvillage dataset']

# %%
dataset_path = "plantvillage/plantvillage dataset"

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# %%
dataset = datasets.ImageFolder(root=dataset_path, transform=transform)

print("Total Images:", len(dataset))
print("Number of Classes:", len(dataset.classes))
print("\nClass Names:\n", dataset.classes)
# Out:
# Total Images: 162916
# Number of Classes: 3
#
# Class Names:
#  ['color', 'grayscale', 'segmented']

# %%
dataloader = DataLoader(dataset, batch_size=16, shuffle=True)
